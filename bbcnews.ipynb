# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\DELL\\Downloads\\archive (2)\\BBCNews.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                              descr  \
# 0           0  chelsea sack mutu  chelsea have sacked adrian ...
# 1           1  record fails to lift lacklustre meet  yelena i...
# 2           2  edu describes tunnel fracas  arsenals edu has ...
# 3           3  ogara revels in ireland victory  ireland flyha...
# 4           4  unclear future for striker baros  liverpool fo...
#
#                                                 tags
# 0  sports, stamford bridge, football association,...
# 1  sports, madrid, birmingham, france, scotland, ...
# 2  sports, derby, brazil, tunnel fracasedu, food,...
# 3  sports, bbc, united kingdom, ireland, brian o'...
# 4  sports, liverpool, daily sport, millennium sta...

# %%
df.shape
# Out:
# (2410, 3)

# %%
bbc_data=df.copy()

# %%
bbc_data
# Out:
#       Unnamed: 0                                              descr  \
# 0              0  chelsea sack mutu  chelsea have sacked adrian ...
# 1              1  record fails to lift lacklustre meet  yelena i...
# 2              2  edu describes tunnel fracas  arsenals edu has ...
# 3              3  ogara revels in ireland victory  ireland flyha...
# 4              4  unclear future for striker baros  liverpool fo...
# ...          ...                                                ...
# 2405        2405  gm in crunch talks on fiat future  fiat will m...
# 2406        2406  uk firm faces venezuelan land row  venezuelan ...
# 2407        2407  winndixie files for bankruptcy  us supermarket...
# 2408        2408  yangtze electrics profits double  yangtze elec...
# 2409        2409  algeria hit by further gas riots  algeria suff...
#
#                                                    tags
# 0     sports, stamford bridge, football association,...
# ...

# %%
bbc_data.columns=["News_ID","Description","Tags"]

# %%
bbc_data
# Out:
#       News_ID                                        Description  \
# 0           0  chelsea sack mutu  chelsea have sacked adrian ...
# 1           1  record fails to lift lacklustre meet  yelena i...
# 2           2  edu describes tunnel fracas  arsenals edu has ...
# 3           3  ogara revels in ireland victory  ireland flyha...
# 4           4  unclear future for striker baros  liverpool fo...
# ...       ...                                                ...
# 2405     2405  gm in crunch talks on fiat future  fiat will m...
# 2406     2406  uk firm faces venezuelan land row  venezuelan ...
# 2407     2407  winndixie files for bankruptcy  us supermarket...
# 2408     2408  yangtze electrics profits double  yangtze elec...
# 2409     2409  algeria hit by further gas riots  algeria suff...
#
#                                                    Tags
# 0     sports, stamford bridge, football association,...
# 1     sports, madrid, birmingham, france, scotland, ...
# ...

# %%
bbc_data.isnull().sum()
# Out:
# News_ID        0
# Description    0
# Tags           0
# dtype: int64

# %%
from langchain.docstore.document import Documnet
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from langchain.docstore.document import Documnet
#
# ImportError: cannot import name 'Documnet' from 'langchain.docstore.document' (C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain\docstore\document.py)

# %%
# !pip install torch==2.4.1+cpu torchvision==0.19.1+cpu torchaudio==2.4.0+cpu --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...
#   Using cached https://download.pytorch.org/whl/cpu/torch-2.4.1%2Bcpu-cp310-cp310-win_amd64.whl (201.8 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cpu/torchvision-0.19.1%2Bcpu-cp310-cp310-win_amd64.whl (1.3 MB)
# ...
#   Using cached https://download-r2.pytorch.org/whl/cpu/torchaudio-2.4.0%2Bcpu-cp310-cp310-win_amd64.whl (2.4 MB)
# ...
#   Obtaining dependency information for typing-extensions>=4.8.0 from https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl.metadata
# ...
# Discarding https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl (from https://download.pytorch.org/whl/cpu/typing-extensions/): Requested typing-extensions>=4.8.0 from https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl (from torch==2.4.1+cpu) has inconsistent Name: expected 'typing-extensions', but metadata has 'typing_extensions'
# ...

# %%
# !pip install langchain
# Out:
# ...
#      ---------------------------------------- 0.0/112.4 kB ? eta -:--:--
#      ---------- ---------------------------- 30.7/112.4 kB 1.3 MB/s eta 0:00:01
#      ------------- ----------------------- 41.0/112.4 kB 393.8 kB/s eta 0:00:01
#      -------------------------------- --- 102.4/112.4 kB 653.6 kB/s eta 0:00:01
#      ------------------------------------ 112.4/112.4 kB 654.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/503.5 kB ? eta -:--:--
#      ----- --------------------------------- 71.7/503.5 kB 1.9 MB/s eta 0:00:01
#      --------- ---------------------------- 122.9/503.5 kB 2.4 MB/s eta 0:00:01
#      --------- ---------------------------- 122.9/503.5 kB 2.4 MB/s eta 0:00:01
#      --------- ---------------------------- 122.9/503.5 kB 2.4 MB/s eta 0:00:01
#      ---------- ------------------------- 143.4/503.5 kB 652.5 kB/s eta 0:00:01
#      ---------- ------------------------- 143.4/503.5 kB 652.5 kB/s eta 0:00:01
# ...

# %%
# !pip install chromadb
